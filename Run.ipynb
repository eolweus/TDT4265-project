# %%
# %run train.py
# Out:
# 2021-04-19 14:19:21,639 U INFO: Loaded configuration file BATCH_SIZE: 12
# EPOCHS: 50
# LEARN_RATE: 0.01
# TEST_SIZE: 50
# VALIDATION_SIZE: 150
# VISUAL_DEBUG: True
# Train Data length: 450
# Test Data length: 0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\Documents\skuul\datasyn\prosjekt\TDT4265-project\train.py in <module>
#     150
#     151 if __name__ == "__main__":
# --> 152     main()
#
# ~\Documents\skuul\datasyn\prosjekt\TDT4265-project\train.py in main()
#     105         plt.show()
#     106     #print(train_data[1].shape)
# --> 107     xb, yb = next(iter(train_data))
#     108     print (xb.shape, yb.shape)
#     109
#
# ~\anaconda3\envs\datasyn\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
# ...
