# %%
# %run train.py
# Out:
# 450
# torch.Size([12, 1, 384, 384]) torch.Size([12, 384, 384])
# Epoch 6/49
# ----------
# Epoch 6/49
# ----------
# train Loss: 0.1006 Acc: 0.0
# ----------
# Epoch 6/49
# ----------
# valid Loss: 0.1200 Acc: 0.0
# ----------
# Time elapsed: 1m 15s
# Epoch 7/49
# ----------
# Epoch 7/49
# ----------
# train Loss: 0.0951 Acc: 0.0
# ----------
# Epoch 7/49
# ----------
# valid Loss: 0.1059 Acc: 0.0
# ----------
# Time elapsed: 2m 32s
# Epoch 8/49
# ----------
# Epoch 8/49
# ----------
# train Loss: 0.0870 Acc: 0.0
# ----------
# Epoch 8/49
# ----------
# valid Loss: 0.1597 Acc: 0.0
# ----------
# Time elapsed: 3m 37s
# Epoch 9/49
# ----------
