# %%
# %run train.py
# Out:
# 2021-04-19 09:38:24,946 U INFO: Loaded configuration file BATCH_SIZE: 12
# EPOCHS: 50
# LEARN_RATE: 0.01
# TEST_SIZE: 50
# VALIDATION_SIZE: 150
# VISUAL_DEBUG: True
# torch.Size([12, 1, 384, 384]) torch.Size([12, 384, 384])
# 2021-04-19 09:38:30,904 U INFO: Unet2D(
#   (conv1): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 32, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
# ...
