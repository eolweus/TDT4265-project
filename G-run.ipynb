# %%
# %run train.py
# Out:
# 2021-04-25 12:46:58,105 U INFO: Loaded configuration file DATASET: TTE
# INPUT:
#   IMAGE_SIZE: (384, 384)
# LOG_DIR: ./logs
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 1
#     OUTPUT_CHANNELS: 128
#   INPUT_CHANNELS: 1
#   NUM_CLASSES: 4
# OUTPUT_DIR: ./outputs
# SOLVER:
#   BATCH_SIZE: 12
#   LEARN_RATE: 0.01
#   TEST_BATCH_SIZE: 6
# TRAINING:
#   EARLY_STOP_COUNT: 0
#   EPOCHS: 50
#   TRAIN_PARTITION: 0.6666666666666666
#   USE_CHECKPOINT: True
#   VISUAL_DEBUG: True
# Train Data length: 400
# torch.Size([12, 1, 384, 384]) torch.Size([12, 384, 384])
# 2021-04-25 12:46:59,518 U.trainer INFO: Loading checkpoint from ./outputs\model_000032.pth
# 2021-04-25 12:46:59,546 U.trainer INFO: Loading optimizer from ./outputs\model_000032.pth
# 2021-04-25 12:46:59,564 U.trainer INFO: Start training ...
# Epoch 32/49
# ----------
# Epoch 32/49
# ----------
# train Loss: 0.1353 Dice: 0.8995091319084167, Acc: 0.9885531663894653
# ----------
# Epoch 32/49
# ----------
# ...
