# %%
# %run train.py
# Out:
# 2021-04-25 14:23:53,088 U INFO: Loaded configuration file DATASET: TTE
# INPUT:
#   IMAGE_SIZE: (384, 384)
# LOG_DIR: ./logs
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 1
#     OUTPUT_CHANNELS: 128
#   INPUT_CHANNELS: 1
#   NUM_CLASSES: 4
# OUTPUT_DIR: ./outputs
# SOLVER:
#   BATCH_SIZE: 12
#   LEARN_RATE: 0.01
#   TEST_BATCH_SIZE: 5
# TRAINING:
#   EARLY_STOP_COUNT: 0
#   EPOCHS: 50
#   TRAIN_PARTITION: 0.6666666666666666
#   USE_CHECKPOINT: True
#   VISUAL_DEBUG: True
# Train Data length: 400
# torch.Size([12, 1, 384, 384]) torch.Size([12, 384, 384])
# 2021-04-25 14:23:54,482 U.trainer INFO: Loading checkpoint from ./outputs\model_000032.pth
# 2021-04-25 14:23:54,511 U.trainer INFO: Loading optimizer from ./outputs\model_000032.pth
# 2021-04-25 14:23:54,530 U.trainer INFO: Start training ...
# Epoch 32/49
# ----------
# Epoch 32/49
# ----------
# train Loss: 0.1358 Dice: 0.8951854705810547, Acc: 0.9879028797149658
# ----------
# Epoch 32/49
# ----------
# ...
