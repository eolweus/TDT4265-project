# %%
# %run train.py
# Out:
# 2021-04-25 16:22:23,934 U INFO: Loaded configuration file DATASET: TTE
# INPUT:
#   IMAGE_SIZE: (384, 384)
# LOG_DIR: ./logs
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 1
#     OUTPUT_CHANNELS: 128
#   INPUT_CHANNELS: 1
#   NUM_CLASSES: 4
# OUTPUT_DIR: ./outputs
# SOLVER:
#   BATCH_SIZE: 10
#   LEARN_RATE: 0.01
#   TEST_BATCH_SIZE: 5
# TRAINING:
#   EARLY_STOP_COUNT: 5
#   EPOCHS: 50
#   TRAIN_PARTITION: 0.6666666666666666
#   USE_CHECKPOINT: True
#   VISUAL_DEBUG: True
# Train Data length: 400
# torch.Size([10, 1, 384, 384]) torch.Size([10, 384, 384])
# 2021-04-25 16:22:25,360 U.trainer INFO: No checkpoint found.
# 2021-04-25 16:22:25,360 U.trainer INFO: Start training ...
# Epoch 0/49
# ----------
# Epoch 0/49
# ----------
# train Loss: 0.9269 Dice: 0.04038418456912041, Acc: 0.6860532760620117
# ----------
# Epoch 0/49
# ----------
# valid Loss: 0.7421 Dice: 0.0, Acc: 0.7332035303115845
# ----------
# ...
